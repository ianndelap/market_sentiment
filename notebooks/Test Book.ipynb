# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
with open('../raw_data/dump.json') as json_file:
    data = json_file.readlines()
    # this line below may take at least 8-10 minutes of processing for 4-5 million rows. It converts all strings in list to actual json objects.
    data = list(map(json.loads, data))
df = pd.DataFrame(data,columns = ['full_text',
'lan',
'datetimestamp',
'created_at',
'favorite_count',
'symbols'])

# %%
df.to_csv(path_or_buf='../market_sentiment/data/data.csv')

# %%
df.head(50)
# Out:
#                                             full_text  lan  datetimestamp  \
# 0   Расцвет человеческого общества зависит от двух...  NaN     1583637560
# 1   I’m waiting for the volatility to settle with ...  NaN     1583637637
# 2                Buy $BTC this is not a fucking drill  NaN     1583637452
# 3                   $btc $btcusd nvm, 8,8k target hit  NaN     1583637470
# 4   Mar 8, 2020 03:12:00 UTC The price of $BTC cur...  NaN     1583637182
# 5   The ongoing spread of coronavirus is forcing i...  NaN     1583637304
# 6   $INTC - Monthly performance of the algo based ...  NaN     1583637405
# 7   Imagine everyone knowing when you transfer mon...  NaN     1583637234
# 8   📈📈24hr Volume Alert!📈📈 $LRC current volume: 98...  NaN     1583637367
# 9   $INTC - Last six months, 35 option alerts peak...  NaN     1583637165
# 10  $BTC plan worked out pretty damn well for the ...  NaN     1583637602
# 11  In todays newsletter we discuss a paradigm shi...  NaN     1583637212
# ...

# %%
df.columns
# Out:
# Index(['essid', 'wit', 'custom_query', 'id_str', 'created_at', 'full_text',
#        'source', 'user_id_str', 'lang', 'favorite_count', 'reply_count',
#        'retweet_count', 'quote_count', 'limited_actions', 'geo', 'place',
#        'coordinates', 'conversation_id_str', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id_str', 'in_reply_to_screen_name',
#        'quoted_status_id_str', 'forward_pivot', 'symbols', 'name',
#        'screen_name', 'datetimestamp', 'urls', 'quoted_user_id_str',
#        'quoted_user_screen_name', 'media', 'hashtags', 'user_mentions'],
#       dtype='object')

# %%
df.corr()
# Out:
#                 favorite_count  reply_count  retweet_count  quote_count  \
# favorite_count        1.000000     0.390186       0.690456     0.410049
# reply_count           0.390186     1.000000       0.375372     0.525165
# retweet_count         0.690456     0.375372       1.000000     0.397264
# quote_count           0.410049     0.525165       0.397264     1.000000
# datetimestamp         0.002179     0.006020      -0.001496     0.000343
#
#                 datetimestamp
# favorite_count       0.002179
# reply_count          0.006020
# retweet_count       -0.001496
# quote_count          0.000343
# datetimestamp        1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
count = 0
for i in df['hashtags'].isnull():
    if i:
        count +=1
    else:
        pass

# %%
df['geo']
# Out:
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 1338808    None
# 1338809    None
# 1338810    None
# 1338811    None
# 1338812    None
# Name: geo, Length: 1338813, dtype: object

# %%
count = 0
for i in df['geo'].isnull():
    if i:
        count +=1
    else:
        pass
count
# Out:
# 1338667

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df = df.drop(['essid',
              'wit',
              'custom_query',
              'limited_actions',
              'in_reply_to_status_id_str',
              'in_reply_to_screen_name',
              'in_reply_to_user_id_str',
              'quoted_status_id_str',
              'geo',
              'place',
              'coordinates',
              'name',
              'quoted_user_id_str',
              'media',
              'user_mentions',
              'forward_pivot',
              'quoted_user_screen_name'],axis=1)

# %%
df['symbols']

# %%
columns = ['full_text',
'lan',
'datetimestamp',
'created_at',
'favorite_count',
'symbols']

# %%
df = df['full_text','lan','datetimestamp','created_at','favorite_count','symbols']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
df[('full_text','lan')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.pyenv/versions/3.8.6/envs/market_sentiment/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('full_text', 'lan')
#
# ...
