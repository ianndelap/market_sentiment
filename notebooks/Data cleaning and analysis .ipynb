# %%
import pandas as pd
import seaborn as sns 
import numpy as np
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

# %%
with open('/Users/ianndelap/code/ianndelap/market_sentiment/raw_data/dump.json') as json_file:
    data = json_file.readlines()
    # this line below may take at least 8-10 minutes of processing for 4-5 million rows. It converts all strings in list to actual json objects.
    data = list(map(json.loads, data))

# %%
df = pd.DataFrame(data)

# %%
x = df.head(50)

# %%
# Out:
#    essid wit                               custom_query               id_str  \
# 0     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491665101160448
# 1     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491987928272896
# 2     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491210916757504
# 3     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491289085898752
# 4     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236490079364939777
# 5     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236490590637916160
# 6     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491015365722112
# 7     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236490296520609792
# 8     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236490856548438016
# 9     []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236490006400610305
# 10    []  []  $BTC%20OR%20$BYND%20OR%20$GE%20OR%20$INTC  1236491842172022784
# ...

# %%
missing_value = (df.isnull().sum()/len(df))*100

# %%
missing_value
# Out:
# essid                          0.000000
# wit                            0.000000
# custom_query                   0.000000
# id_str                         0.000000
# created_at                     0.000000
# full_text                      0.000000
# source                         0.000000
# user_id_str                    0.000000
# lang                           0.000000
# favorite_count                 0.000000
# reply_count                    0.000000
# retweet_count                  0.000000
# quote_count                    0.000000
# limited_actions              100.000000
# geo                           99.989095
# place                         99.510985
# coordinates                   99.989095
# conversation_id_str            0.000000
# in_reply_to_status_id_str     87.170949
# in_reply_to_user_id_str       86.329383
# in_reply_to_screen_name       86.329383
# quoted_status_id_str          93.110912
# forward_pivot                100.000000
# ...

# %%
X = df[['full_text','favorite_count','symbols','datetimestamp','created_at','lang','custom_query']]

# %%
data = np.asarray(missing_value).reshape(33,1)
sns.heatmap(data)
plt.show()

# %%
# Out:
# pandas.core.series.Series

# %%
df['new'] = [','.join(map(str, l)) for l in df['symbols']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/99/ckqc944s1nl57yz05vhcmt6w0000gn/T/ipykernel_2029/2856750881.py in <module>
# ----> 1 df['new'] = [','.join(map(str, l)) for l in df['symbols']]
#
# /var/folders/99/ckqc944s1nl57yz05vhcmt6w0000gn/T/ipykernel_2029/2856750881.py in <listcomp>(.0)
# ----> 1 df['new'] = [','.join(map(str, l)) for l in df['symbols']]
#
# TypeError: 'float' object is not iterable

# %%
df['new_column'] = df.symbols.str.findall('btc')

# %%
df['new_column']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#            ..
# 1338808   NaN
# 1338809   NaN
# 1338810   NaN
# 1338811   NaN
# 1338812   NaN
# Name: new_column, Length: 1338813, dtype: float64
